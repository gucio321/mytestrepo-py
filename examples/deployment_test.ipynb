# %% [markdown]
# <a href="https://colab.research.google.com/github/gucio321/mytestrepo-py/blob/master/examples/deployment_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MyTestRepo-py
# This is a deployment test for distributed version of [github.com/gucio321/mytestrepo-py](https://github.com/gucio321/mytestrepo-py).
#
# Feel free to check out projects readme as well ass [the documentation](https://gucio321.github.io/mytestrepo-py) and [testPyPi package overview](https://test.pypi.org/p/mytestrepo-py-gucio321).

# %%
# !python3 -m pip install --index-url https://test.pypi.org/simple/ mytestrepo_py_gucio321==1.0.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: mytestrepo_py_gucio321
#     Found existing installation: mytestrepo_py_gucio321 0.0.9
#     Uninstalling mytestrepo_py_gucio321-0.0.9:
#       Successfully uninstalled mytestrepo_py_gucio321-0.0.9
# ...

# %%
from mytestrepo_py_gucio321.example import sum_numbers

# %%
print(sum_numbers(3,4), sum_numbers(4,3))
# Out:
# 7 7

# %%
help(sum_numbers)
# Out:
# Help on function sum_numbers in module mytestrepo_py_gucio321.example:
#
# sum_numbers(a: [<class 'int'>, <class 'float'>], b: [<class 'int'>, <class 'float'>] = 0) -> [<class 'int'>, <class 'float'>]
#     sum returns a sum of 2 integer numbers.
#
#     :param a: first number
#     :param b: second number, default is 0
#     :return: sum of a and b
